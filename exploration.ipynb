# %%
import pandas as pd

# %%
pd.read_csv("data/F1_tweets.csv")[["date", "text", "source"]]
# Out:
# C:\Users\Michi\AppData\Local\Temp\ipykernel_14392\541402625.py:1: DtypeWarning: Columns (5,6,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("data/F1_tweets.csv")[["date", "text", "source"]]
#                        date  \
# 0       2021-08-01 23:59:18
# 1       2021-08-01 23:59:10
# 2       2021-08-01 23:58:48
# 3       2021-08-01 23:58:11
# 4       2021-08-01 23:57:40
# ...                     ...
# 632383  2022-08-20 22:18:08
# 632384  2022-08-20 22:17:35
# 632385  2022-08-20 22:16:05
# 632386  2022-08-20 22:11:04
# 632387  2022-08-20 22:10:27
#
#                                                      text               source
# 0       The next great #F1 duo!!! @ESPNF1 https://t.co...   Twitter for iPhone
# 1       @F1 What if…Hamilton would have gone to the pi...   Twitter for iPhone
# 2       This has been a tiring #f1 day... https://t.co...  Twitter for Android
# ...

# %%
races = pd.read_csv("data/F1_stats/circuits.csv")[["circuitId","name","location","country"]]
races
# Out:
#     circuitId                                  name      location  \
# 0           1        Albert Park Grand Prix Circuit     Melbourne
# 1           2          Sepang International Circuit  Kuala Lumpur
# 2           3         Bahrain International Circuit        Sakhir
# 3           4        Circuit de Barcelona-Catalunya      Montmeló
# 4           5                         Istanbul Park      Istanbul
# ..        ...                                   ...           ...
# 71         75    Autódromo Internacional do Algarve      Portimão
# 72         76  Autodromo Internazionale del Mugello       Mugello
# 73         77               Jeddah Corniche Circuit        Jeddah
# 74         78          Losail International Circuit     Al Daayen
# 75         79         Miami International Autodrome         Miami
#
#          country
# 0      Australia
# 1       Malaysia
# 2        Bahrain
# 3          Spain
# 4         Turkey
# ..           ...
# 71      Portugal
# 72         Italy
# ...

# %%
drivers = pd.read_csv("data/F1_stats/drivers.csv")
drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  1995-09-23
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
# ...

# %%
results = pd.read_csv("data/F1_stats/results.csv")
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25655     25661    1086       825            210     20    13       16
# 25656     25662    1086       848              3     23    17       17
# 25657     25663    1086       849              3      6    19       18
# 25658     25664    1086       852            213     22    16       19
# 25659     25665    1086       822             51     77     8       20
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
driver_results = results.join(drivers, on="driverId", how='left', lsuffix='_left', rsuffix='_right')[["position","positionOrder","driverRef","circuitId"]]
driver_results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Michi\Documents\JADS\Data engineering\f1-sentiment-analysis\exploration.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Michi/Documents/JADS/Data%20engineering/f1-sentiment-analysis/exploration.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> driver_results = results.join(drivers, on="driverId", how='left', lsuffix='_left', rsuffix='_right')[["position","positionOrder","driverRef","circuitId"]]
#       <a href='vscode-notebook-cell:/c%3A/Users/Michi/Documents/JADS/Data%20engineering/f1-sentiment-analysis/exploration.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> driver_results
#
# File c:\Users\Michi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# ...

# %%
from google.cloud import storage


def write_read(bucket_name, blob_name):

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    with blob.open("r") as f:
        print(f.read())
